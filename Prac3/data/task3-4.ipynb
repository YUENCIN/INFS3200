# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
values = np.array([[[0.0002883153408240923, 1.0, 0.0005764644780957093], [0.352112676056338, 0.9433962264150944, 0.5128205128205129], [0.5161290322580645, 0.9056603773584906, 0.6575342465753424], [0.8144329896907216, 0.7452830188679245, 0.7783251231527093], [0.9166666666666666, 0.7264150943396226, 0.8105263157894737], [0.9156626506024096, 0.7169811320754716, 0.8042328042328042]], [[0.0002883153408240923, 1.0, 0.0005764644780957093], [0.0008096472584876724, 0.9811320754716981, 0.0016179593487713622], [0.002102916745526045, 0.9433962264150944, 0.004196479153989803], [0.012833031106151485, 0.8679245283018868, 0.025292096219931268], [0.09016393442622951, 0.8301886792452831, 0.16266173752310537], [0.5804195804195804, 0.7830188679245284, 0.6666666666666666]], [[0.0002883153408240923, 1.0, 0.0005764644780957093], [0.19433198380566802, 0.9056603773584906, 0.32], [0.4642857142857143, 0.8584905660377359, 0.6026490066225166], [0.8095238095238095, 0.8018867924528302, 0.8056872037914692], [0.8709677419354839, 0.7641509433962265, 0.8140703517587939], [0.9058823529411765, 0.7264150943396226, 0.8062827225130891]], [[0.0002883153408240923, 1.0, 0.0005764644780957093], [0.36538461538461536, 0.8962264150943396, 0.5191256830601092], [0.6541353383458647, 0.8207547169811321, 0.7280334728033473], [0.8350515463917526, 0.7641509433962265, 0.7980295566502463], [0.9069767441860465, 0.7358490566037735, 0.8124999999999999], [0.9156626506024096, 0.7169811320754716, 0.8042328042328042]], [[0.0002883153408240923, 1.0, 0.0005764644780957093], [0.4946808510638298, 0.8773584905660378, 0.6326530612244898], [0.7433628318584071, 0.7924528301886793, 0.767123287671233], [0.8571428571428571, 0.7358490566037735, 0.7918781725888324], [0.9058823529411765, 0.7264150943396226, 0.8062827225130891], [0.9156626506024096, 0.7169811320754716, 0.8042328042328042]]])

# %%
q = [0, 1, 2, 3, 4]
for q_group,q_value in zip(values,q):
    thresh = [0, 0.375, 0.5, 0.625, 0.75, 0.875]
    plt.plot(thresh, q_group[:,0], label='Precision')
    plt.plot(thresh, q_group[:,1], label='Recall')
    plt.plot(thresh, q_group[:,2], label='F')
    plt.xlabel("q="+str(q_value))
    plt.ylabel('Value')
    plt.legend(loc='best')
    plt.show()

# %%
q = [0, 1, 2, 3, 4]
q_values = []
index = 3
for q_group in values:
    q_values.append(q_group[index])
q_values = np.array(q_values)
plt.plot(q, q_values[:,0], label='Precision')
plt.plot(q, q_values[:,1], label='Recall')
plt.plot(q, q_values[:,2], label='F')
plt.xlabel("q")
plt.ylabel('Value')
plt.legend(loc='best')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
value_ed = np.array([[0.0002883153408240923, 1.0, 0.0005764644780957093], [0.012904084076094186, 0.9150943396226415, 0.025449298176570902], [0.06852409638554217, 0.8584905660377359, 0.1269177126917713], [0.3789954337899543, 0.7830188679245284, 0.5107692307692308], [0.7843137254901961, 0.7547169811320755, 0.7692307692307692], [0.8837209302325582, 0.7169811320754716, 0.7916666666666666]])

# %%
thresh = [0, 0.375, 0.5, 0.625, 0.75, 0.875]
plt.plot(thresh, value_ed[:,0], label='Precision')
plt.plot(thresh, value_ed[:,1], label='Recall')
plt.plot(thresh, value_ed[:,2], label='F')
plt.xlabel("Threshold")
plt.ylabel('Value')
plt.legend(loc='best')
plt.show()
